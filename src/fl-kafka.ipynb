# %%
# %load_ext autoreload
# %autoreload 2

import asyncio, copy, os, socket, sys, time
from functools import partial
from multiprocessing import Pool, Process
from pathlib import Path
from tqdm import tqdm

import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../")))
from libs import agg, data, fl, log, nn, plot, poison, resnet, sim, wandb
from libs.distributed import *
from cfgs.fedargs import *

# %%
project = 'fl-kafka'
fedargs.num_clients = 5
name = 'fedavg-cnn-mnist-na'

# Save Logs To File (info | debug | warning | error | critical) [optional]
log.init("info")
#log.init("info", name)
#log.init("debug", name)

fedargs.tb = SummaryWriter('../out/runs/' + project + '/' + name, comment="fl")
plot = plot.init(name, project)
wb = wandb.init(name, project)
# Out:
# wandb: Currently logged in as: kasyah (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/kasyah/fl-kafka/runs/2da0amme" target="_blank">fedavg-cnn-mnist-na</a></strong> to <a href="https://wandb.ai/kasyah/fl-kafka" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
use_cuda = fedargs.cuda and torch.cuda.is_available()
torch.manual_seed(fedargs.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

# %%
host = socket.gethostname()
clients = [host + "(" + str(client + 1) + ")" for client in range(fedargs.num_clients)]

# %%
# Distributed topology
dt = Distributed(clients, fedargs.broker_ip, fedargs.schema_ip, fedargs.wait_to_consume)

# %%
# Initialize Global and Client models
global_model = copy.deepcopy(fedargs.model)
# Load Data to clients
train_data, test_data = data.load_dataset(fedargs.dataset)

# %%
clients_data = data.split_data(train_data, clients)

# %%
client_train_loaders, client_test_loaders = data.load_client_data(clients_data, fedargs.client_batch_size, 0.2, **kwargs)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=fedargs.test_batch_size, shuffle=True, **kwargs)

client_details = {
        client: {"train_loader": client_train_loaders[client],
                 "test_loader": client_test_loaders[client],
                 "model": copy.deepcopy(global_model),
                 "model_update": None}
        for client in clients
    }

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def process(client, epoch, dt, model, train_loader, test_loader, fedargs, device):
    log.info("Epoch: {}, Processing Client {}".format(epoch, client))
    
    # Consume and Average, epoch passed is actually prev epoch, for which we want to consume updates
    client_model_updates = dt.consume_model(client, fedargs.topic, model, epoch)
    
    # Pop one's own update
    if client in client_model_updates:
        client_model_updates.pop(client)

    log.info("Epoch: {}, Client {} received {} model update(s) from {}".format(epoch, client, 
                                                                               len(client_model_updates), 
                                                                               list(client_model_updates.keys())))
    
    if len(client_model_updates) != 0:
        model = fl.federated_avg(client_model_updates, model)

    # Train    
    model_update, model, loss = fedargs.train_func(model, train_loader, 
                                                   fedargs.learning_rate,
                                                   fedargs.weight_decay,
                                                   fedargs.local_rounds, device)

    # Publish
    epoch = epoch + 1
    dt.produce_model(client, fedargs.topic, model_update, epoch)

    log.jsondebug(loss, "Epoch {} : Federated Training loss, Client {}".format(epoch, client))
    log.modeldebug(model, "Epoch {}: Client {} Update".format(epoch, client))

    # Test, Plot and Log
    test_output = fedargs.eval_func(model, test_loader, device)
    fedargs.tb.add_scalar("Accuracy/" + client, test_output["accuracy"], epoch)
    fedargs.tb.add_scalar("Test Loss/" + client, test_output["test_loss"], epoch)
    plot.alog(client, {epoch: {"time": time.time(), "acc": test_output["accuracy"], "loss": test_output["test_loss"]}})
    wb.log({client: {"epoch": epoch, "time": time.time(), "acc": test_output["accuracy"], "loss": test_output["test_loss"]}})
    log.jsoninfo(test_output, "Test Outut after Epoch {} of {} for Client {}".format(epoch, fedargs.epochs, client))

    return model

# %%
import time
start_time = time.time()

# Federated Training
for epoch in tqdm(range(fedargs.epochs)):
    log.info("Federated Training Epoch {} of {}".format(epoch, fedargs.epochs))

    # Clients  
    tasks = [process(client, epoch, dt, client_details[client]['model'],
                     client_details[client]['train_loader'],
                     client_details[client]['test_loader'],
                     fedargs, device) for client in clients]
    try:
        updates = fedargs.loop.run_until_complete(asyncio.gather(*tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling tasks...")
        tasks.cancel()
        fedargs.loop.run_forever()
        tasks.exception()
    
    for client, update in zip(clients, updates):
        client_details[client]['model'] = update
    
print(time.time() - start_time)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]2021-11-06 13:25:44,101 - <ipython-input-10-d06f8893748b>::<module>(l:6) : Federated Training Epoch 0 of 51 [MainProcess : MainThread (INFO)]
# 2021-11-06 13:25:44,197 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:25:44,198 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:25:44,198 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:25:44,202 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:25:44,205 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:25:54,869 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 0, Client bladecluster.iitp.org(5) received 14 model update(s) from ['bladecluster.iitp.org(14)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(16)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(25)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(30)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:25:54,879 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 0, Client bladecluster.iitp.org(4) received 13 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(14)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(16)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(25)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:25:54,908 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 0, Client bladecluster.iitp.org(1) received 11 model update(s) from ['bladecluster.iitp.org(15)', 'bladecluster.iitp.org(14)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(16)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(10)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:25:54,921 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 0, Client bladecluster.iitp.org(3) received 15 model update(s) from ['bladecluster.iitp.org(15)', 'bladecluster.iitp.org(14)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(16)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(25)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(30)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:25:54,921 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 0, Client bladecluster.iitp.org(2) received 14 model update(s) from ['bladecluster.iitp.org(12)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(16)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(25)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(30)', 'bladecluster.iitp.org(20)', 'bladecluster.iitp.org(8)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:26:18,871 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:26:19,032 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:26:19,620 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:26:19,827 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:26:20,161 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to pyflx [0] at offset 1236 [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:26:20,163 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:26:20,602 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:26:20,732 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to pyflx [0] at offset 1237 [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:26:20,948 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:26:20,976 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:26:21,356 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to pyflx [0] at offset 1238 [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:26:21,360 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:26:21,614 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:26:21,657 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to pyflx [0] at offset 1239 [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:26:22,398 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to pyflx [0] at offset 1240 [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:26:27,345 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 1 of 51 for Client bladecluster.iitp.org(1) {
#     "accuracy": 82.16666666666667,
#     "correct": 1972,
#     "test_loss": 0.5952641014258067
# } [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:26:27,416 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 1 of 51 for Client bladecluster.iitp.org(4) {
#     "accuracy": 80.45833333333333,
#     "correct": 1931,
#     "test_loss": 0.6413459646701812
# } [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:26:27,513 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 1 of 51 for Client bladecluster.iitp.org(5) {
#     "accuracy": 80.75,
#     "correct": 1938,
#     "test_loss": 0.6291550878683726
# } [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:26:27,576 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 1 of 51 for Client bladecluster.iitp.org(3) {
#     "accuracy": 81.45833333333333,
#     "correct": 1955,
#     "test_loss": 0.6418026375770569
# } [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:26:27,799 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 1 of 51 for Client bladecluster.iitp.org(2) {
#     "accuracy": 81.16666666666667,
#     "correct": 1948,
#     "test_loss": 0.6379255612691244
# } [MainProcess : asyncio_1 (INFO)]
#   2%|▏         | 1/51 [00:44<36:42, 44.05s/it]2021-11-06 13:26:27,840 - <ipython-input-10-d06f8893748b>::<module>(l:6) : Federated Training Epoch 1 of 51 [MainProcess : MainThread (INFO)]
# 2021-11-06 13:26:27,937 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:26:27,954 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:26:27,969 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:26:27,970 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:26:27,973 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:26:38,277 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 1, Client bladecluster.iitp.org(5) received 13 model update(s) from ['bladecluster.iitp.org(20)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(43)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:26:38,278 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 1, Client bladecluster.iitp.org(1) received 14 model update(s) from ['bladecluster.iitp.org(25)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(30)', 'bladecluster.iitp.org(20)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(43)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(37)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:26:38,295 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 1, Client bladecluster.iitp.org(2) received 14 model update(s) from ['bladecluster.iitp.org(29)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(43)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(34)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:26:38,297 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 1, Client bladecluster.iitp.org(3) received 13 model update(s) from ['bladecluster.iitp.org(20)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(43)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:26:38,299 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 1, Client bladecluster.iitp.org(4) received 13 model update(s) from ['bladecluster.iitp.org(22)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(30)', 'bladecluster.iitp.org(20)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(43)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(37)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:27:16,626 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:27:16,859 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:27:17,628 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:27:17,717 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to pyflx [0] at offset 1242 [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:27:17,845 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:27:18,696 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to pyflx [0] at offset 1243 [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:27:19,253 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:27:19,413 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:27:20,060 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:27:20,235 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:27:20,315 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to pyflx [0] at offset 1244 [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:27:20,610 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:27:20,767 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:27:21,122 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to pyflx [0] at offset 1245 [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:27:21,674 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to pyflx [0] at offset 1246 [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:27:22,012 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 2 of 51 for Client bladecluster.iitp.org(1) {
#     "accuracy": 81.875,
#     "correct": 1965,
#     "test_loss": 0.6043912931283315
# } [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:27:23,370 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 2 of 51 for Client bladecluster.iitp.org(4) {
#     "accuracy": 80.58333333333333,
#     "correct": 1934,
#     "test_loss": 0.627191971540451
# } [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:27:24,170 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 2 of 51 for Client bladecluster.iitp.org(3) {
#     "accuracy": 82.70833333333333,
#     "correct": 1985,
#     "test_loss": 0.5974301544825236
# } [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:27:24,518 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 2 of 51 for Client bladecluster.iitp.org(5) {
#     "accuracy": 82.0,
#     "correct": 1968,
#     "test_loss": 0.6082713298002879
# } [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:27:24,717 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 2 of 51 for Client bladecluster.iitp.org(2) {
#     "accuracy": 79.0,
#     "correct": 1896,
#     "test_loss": 0.6716722249984741
# } [MainProcess : asyncio_3 (INFO)]
#   4%|▍         | 2/51 [01:40<42:09, 51.62s/it]2021-11-06 13:27:24,752 - <ipython-input-10-d06f8893748b>::<module>(l:6) : Federated Training Epoch 2 of 51 [MainProcess : MainThread (INFO)]
# 2021-11-06 13:27:24,837 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:27:24,848 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:27:24,857 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:27:24,873 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:27:24,874 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:27:34,989 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 2, Client bladecluster.iitp.org(2) received 13 model update(s) from ['bladecluster.iitp.org(35)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(16)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(18)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(29)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:27:35,007 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 2, Client bladecluster.iitp.org(5) received 13 model update(s) from ['bladecluster.iitp.org(45)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(16)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(18)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:27:35,018 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 2, Client bladecluster.iitp.org(3) received 11 model update(s) from ['bladecluster.iitp.org(45)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(16)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:27:35,026 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 2, Client bladecluster.iitp.org(4) received 13 model update(s) from ['bladecluster.iitp.org(40)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(19)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:27:35,028 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 2, Client bladecluster.iitp.org(1) received 14 model update(s) from ['bladecluster.iitp.org(40)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(8)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(16)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:28:12,998 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:28:13,210 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:28:14,083 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to pyflx [0] at offset 1247 [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:28:14,623 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:28:14,919 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:28:15,092 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:28:15,182 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:28:15,688 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to pyflx [0] at offset 1248 [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:28:15,990 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to pyflx [0] at offset 1249 [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:28:16,656 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:28:16,858 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:28:17,379 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:28:17,515 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:28:17,717 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to pyflx [0] at offset 1250 [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:28:18,439 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to pyflx [0] at offset 1251 [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:28:18,854 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 3 of 51 for Client bladecluster.iitp.org(5) {
#     "accuracy": 81.375,
#     "correct": 1953,
#     "test_loss": 0.6248472925027212
# } [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:28:19,908 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 3 of 51 for Client bladecluster.iitp.org(4) {
#     "accuracy": 79.29166666666667,
#     "correct": 1903,
#     "test_loss": 0.6505577576160431
# } [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:28:20,017 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 3 of 51 for Client bladecluster.iitp.org(2) {
#     "accuracy": 78.79166666666667,
#     "correct": 1891,
#     "test_loss": 0.6624147148927053
# } [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:28:20,493 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 3 of 51 for Client bladecluster.iitp.org(1) {
#     "accuracy": 82.20833333333334,
#     "correct": 1973,
#     "test_loss": 0.6000270291169485
# } [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:28:20,788 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 3 of 51 for Client bladecluster.iitp.org(3) {
#     "accuracy": 81.75,
#     "correct": 1962,
#     "test_loss": 0.6101917886734008
# } [MainProcess : asyncio_4 (INFO)]
#   6%|▌         | 3/51 [02:37<42:55, 53.66s/it]2021-11-06 13:28:20,818 - <ipython-input-10-d06f8893748b>::<module>(l:6) : Federated Training Epoch 3 of 51 [MainProcess : MainThread (INFO)]
# 2021-11-06 13:28:20,838 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:28:20,895 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:28:20,895 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:28:20,895 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:28:20,897 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:28:31,580 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 3, Client bladecluster.iitp.org(2) received 13 model update(s) from ['bladecluster.iitp.org(15)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(14)', 'bladecluster.iitp.org(21)', 'bladecluster.iitp.org(20)', 'bladecluster.iitp.org(30)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:28:31,594 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 3, Client bladecluster.iitp.org(1) received 14 model update(s) from ['bladecluster.iitp.org(9)', 'bladecluster.iitp.org(18)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(14)', 'bladecluster.iitp.org(21)', 'bladecluster.iitp.org(20)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:28:31,635 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 3, Client bladecluster.iitp.org(4) received 14 model update(s) from ['bladecluster.iitp.org(16)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(18)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(14)', 'bladecluster.iitp.org(21)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:28:31,637 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 3, Client bladecluster.iitp.org(5) received 13 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(14)', 'bladecluster.iitp.org(21)', 'bladecluster.iitp.org(20)', 'bladecluster.iitp.org(30)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:28:31,638 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 3, Client bladecluster.iitp.org(3) received 13 model update(s) from ['bladecluster.iitp.org(9)', 'bladecluster.iitp.org(18)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(29)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(13)', 'bladecluster.iitp.org(6)', 'bladecluster.iitp.org(7)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(28)', 'bladecluster.iitp.org(14)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:29:08,181 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:29:08,401 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:29:08,792 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:29:08,964 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:29:09,253 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to pyflx [0] at offset 1253 [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:29:09,874 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to pyflx [0] at offset 1254 [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:29:12,526 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:29:12,718 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:29:13,191 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:29:13,367 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:29:13,479 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 4 of 51 for Client bladecluster.iitp.org(2) {
#     "accuracy": 79.41666666666667,
#     "correct": 1906,
#     "test_loss": 0.6755590991179148
# } [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:29:13,582 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to pyflx [0] at offset 1255 [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:29:13,962 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 4 of 51 for Client bladecluster.iitp.org(3) {
#     "accuracy": 79.125,
#     "correct": 1899,
#     "test_loss": 0.6529150811831156
# } [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:29:14,350 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to pyflx [0] at offset 1256 [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:29:14,360 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:29:14,520 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:29:15,401 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to pyflx [0] at offset 1257 [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:29:15,870 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 4 of 51 for Client bladecluster.iitp.org(4) {
#     "accuracy": 78.45833333333333,
#     "correct": 1883,
#     "test_loss": 0.6853057551383972
# } [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:29:16,272 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 4 of 51 for Client bladecluster.iitp.org(1) {
#     "accuracy": 79.79166666666667,
#     "correct": 1915,
#     "test_loss": 0.6446159235636393
# } [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:29:16,889 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 4 of 51 for Client bladecluster.iitp.org(5) {
#     "accuracy": 79.33333333333333,
#     "correct": 1904,
#     "test_loss": 0.6647599323590596
# } [MainProcess : asyncio_4 (INFO)]
#   8%|▊         | 4/51 [03:33<42:47, 54.62s/it]2021-11-06 13:29:16,912 - <ipython-input-10-d06f8893748b>::<module>(l:6) : Federated Training Epoch 4 of 51 [MainProcess : MainThread (INFO)]
# 2021-11-06 13:29:16,958 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:29:16,990 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:29:16,992 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:29:17,003 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:29:17,005 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:29:27,431 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 4, Client bladecluster.iitp.org(2) received 12 model update(s) from ['bladecluster.iitp.org(12)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(17)', 'bladecluster.iitp.org(32)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(25)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(31)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(37)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:29:27,437 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 4, Client bladecluster.iitp.org(5) received 16 model update(s) from ['bladecluster.iitp.org(10)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(17)', 'bladecluster.iitp.org(32)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(25)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(31)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(35)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:29:27,463 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 4, Client bladecluster.iitp.org(4) received 15 model update(s) from ['bladecluster.iitp.org(20)', 'bladecluster.iitp.org(30)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(17)', 'bladecluster.iitp.org(32)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(25)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(31)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:29:27,481 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 4, Client bladecluster.iitp.org(1) received 14 model update(s) from ['bladecluster.iitp.org(30)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(17)', 'bladecluster.iitp.org(32)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(25)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(31)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:29:27,491 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 4, Client bladecluster.iitp.org(3) received 12 model update(s) from ['bladecluster.iitp.org(21)', 'bladecluster.iitp.org(20)', 'bladecluster.iitp.org(30)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(12)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(17)', 'bladecluster.iitp.org(32)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(24)', 'bladecluster.iitp.org(26)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:02,320 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:02,672 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:02,893 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:02,928 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:03,646 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:03,646 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to pyflx [0] at offset 1259 [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:03,763 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to pyflx [0] at offset 1260 [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:03,935 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:04,727 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to pyflx [0] at offset 1261 [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:05,148 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:05,323 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:06,253 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to pyflx [0] at offset 1262 [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:07,597 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:30:07,765 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:30:08,371 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 5 of 51 for Client bladecluster.iitp.org(1) {
#     "accuracy": 79.45833333333333,
#     "correct": 1907,
#     "test_loss": 0.6563673039277395
# } [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:08,440 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 5 of 51 for Client bladecluster.iitp.org(4) {
#     "accuracy": 81.41666666666667,
#     "correct": 1954,
#     "test_loss": 0.6253654078642528
# } [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:08,646 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to pyflx [0] at offset 1263 [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:30:08,945 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 5 of 51 for Client bladecluster.iitp.org(2) {
#     "accuracy": 81.41666666666667,
#     "correct": 1954,
#     "test_loss": 0.594345713853836
# } [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:09,553 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 5 of 51 for Client bladecluster.iitp.org(3) {
#     "accuracy": 80.04166666666667,
#     "correct": 1921,
#     "test_loss": 0.6533449467023213
# } [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:10,274 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 5 of 51 for Client bladecluster.iitp.org(5) {
#     "accuracy": 81.95833333333333,
#     "correct": 1967,
#     "test_loss": 0.5998984162012736
# } [MainProcess : asyncio_4 (INFO)]
#  10%|▉         | 5/51 [04:26<41:32, 54.18s/it]2021-11-06 13:30:10,313 - <ipython-input-10-d06f8893748b>::<module>(l:6) : Federated Training Epoch 5 of 51 [MainProcess : MainThread (INFO)]
# 2021-11-06 13:30:10,338 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:10,379 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:10,399 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:10,400 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:30:10,418 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:20,658 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 5, Client bladecluster.iitp.org(3) received 14 model update(s) from ['bladecluster.iitp.org(25)', 'bladecluster.iitp.org(27)', 'bladecluster.iitp.org(31)', 'bladecluster.iitp.org(34)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(44)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:20,659 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 5, Client bladecluster.iitp.org(2) received 14 model update(s) from ['bladecluster.iitp.org(35)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)', 'bladecluster.iitp.org(43)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:20,827 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 5, Client bladecluster.iitp.org(1) received 15 model update(s) from ['bladecluster.iitp.org(34)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:20,845 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 5, Client bladecluster.iitp.org(5) received 12 model update(s) from ['bladecluster.iitp.org(40)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:30:20,896 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 5, Client bladecluster.iitp.org(4) received 16 model update(s) from ['bladecluster.iitp.org(34)', 'bladecluster.iitp.org(37)', 'bladecluster.iitp.org(35)', 'bladecluster.iitp.org(40)', 'bladecluster.iitp.org(42)', 'bladecluster.iitp.org(38)', 'bladecluster.iitp.org(46)', 'bladecluster.iitp.org(36)', 'bladecluster.iitp.org(33)', 'bladecluster.iitp.org(41)', 'bladecluster.iitp.org(44)', 'bladecluster.iitp.org(39)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)', 'bladecluster.iitp.org(43)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:54,267 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:54,468 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:55,025 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:55,257 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:55,519 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to pyflx [0] at offset 1265 [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:30:55,572 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:55,805 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:56,098 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to pyflx [0] at offset 1266 [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:30:56,706 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to pyflx [0] at offset 1267 [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:30:56,708 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:56,958 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:57,520 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic pyflx. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:30:57,739 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:30:57,767 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to pyflx [0] at offset 1268 [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:30:58,603 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to pyflx [0] at offset 1269 [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:31:00,293 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 6 of 51 for Client bladecluster.iitp.org(4) {
#     "accuracy": 76.91666666666667,
#     "correct": 1846,
#     "test_loss": 0.7546039231618246
# } [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:31:00,809 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 6 of 51 for Client bladecluster.iitp.org(2) {
#     "accuracy": 74.70833333333333,
#     "correct": 1793,
#     "test_loss": 0.7812519788742065
# } [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:31:01,127 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 6 of 51 for Client bladecluster.iitp.org(3) {
#     "accuracy": 79.75,
#     "correct": 1914,
#     "test_loss": 0.6835012213389079
# } [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:31:01,366 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 6 of 51 for Client bladecluster.iitp.org(1) {
#     "accuracy": 79.45833333333333,
#     "correct": 1907,
#     "test_loss": 0.6754032814502716
# } [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:31:01,682 - <ipython-input-9-988a6d4ae51a>::process(l:44) : Test Outut after Epoch 6 of 51 for Client bladecluster.iitp.org(5) {
#     "accuracy": 79.0,
#     "correct": 1896,
#     "test_loss": 0.7020429635047912
# } [MainProcess : asyncio_4 (INFO)]
#  12%|█▏        | 6/51 [05:17<39:55, 53.23s/it]2021-11-06 13:31:01,722 - <ipython-input-10-d06f8893748b>::<module>(l:6) : Federated Training Epoch 6 of 51 [MainProcess : MainThread (INFO)]
# 2021-11-06 13:31:01,781 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:31:01,792 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:31:01,793 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-06 13:31:01,798 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:31:01,798 - <ipython-input-9-988a6d4ae51a>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:31:11,992 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 6, Client bladecluster.iitp.org(3) received 14 model update(s) from ['bladecluster.iitp.org(39)', 'bladecluster.iitp.org(45)', 'bladecluster.iitp.org(47)', 'bladecluster.iitp.org(48)', 'bladecluster.iitp.org(43)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(5)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-06 13:31:12,009 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 6, Client bladecluster.iitp.org(2) received 14 model update(s) from ['bladecluster.iitp.org(49)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(29)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-06 13:31:12,010 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 6, Client bladecluster.iitp.org(5) received 12 model update(s) from ['bladecluster.iitp.org(43)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(26)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-06 13:31:12,011 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 6, Client bladecluster.iitp.org(4) received 12 model update(s) from ['bladecluster.iitp.org(49)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(26)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-06 13:31:12,011 - <ipython-input-9-988a6d4ae51a>::process(l:18) : Epoch: 6, Client bladecluster.iitp.org(1) received 15 model update(s) from ['bladecluster.iitp.org(43)', 'bladecluster.iitp.org(49)', 'bladecluster.iitp.org(50)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(23)', 'bladecluster.iitp.org(22)', 'bladecluster.iitp.org(9)', 'bladecluster.iitp.org(10)', 'bladecluster.iitp.org(11)', 'bladecluster.iitp.org(15)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(19)', 'bladecluster.iitp.org(26)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(29)'] [MainProcess : asyncio_0 (INFO)]

# %% [markdown]
# <h1> End </h1>
