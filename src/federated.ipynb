# %%
# %load_ext autoreload
# %autoreload 2

import os, sys
import copy
import socket
from tqdm import tqdm
import torch
import pickle
from torch import optim
from pathlib import Path
from torch.utils.tensorboard import SummaryWriter

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../")))
from libs import fl, nn, agg, data, poison, log

# %%
# Save Logs To File (info | debug | warning | error | critical) [optional]
log.init("info")
#log.init("info", "federated.log")
#log.init("debug", "flkafka.log")

# %%
class FedArgs():
    def __init__(self):
        self.num_clients = 50
        self.epochs = 10
        self.local_rounds = 1
        self.client_batch_size = 32
        self.test_batch_size = 128
        self.learning_rate = 1e-4
        self.weight_decay = 1e-5
        self.cuda = False
        self.seed = 1
        self.tb = SummaryWriter('../out/runs/federated/FLTrust', comment="Mnist Centralized Federated training")

fedargs = FedArgs()

# %%
use_cuda = fedargs.cuda and torch.cuda.is_available()
torch.manual_seed(fedargs.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

# %%
host = socket.gethostname()
clients = [host + "(" + str(client + 1) + ")" for client in range(fedargs.num_clients)]

# %%
#Initialize Global and Client models
global_model = nn.ModelMNIST()
client_models = {client: copy.deepcopy(global_model) for client in clients}

# Function for training
def train_model(model, train_loader, fedargs, device):
    model, loss = fl.client_update(model,
                                train_loader,
                                fedargs.learning_rate,
                                fedargs.weight_decay,
                                fedargs.local_rounds,
                                device)
    return model, loss

# %%
# Load MNIST Data to clients
train_data, test_data = data.load_dataset("mnist")

# %%
clients_data = data.split_data(train_data, clients)

# %%
client_train_loaders, _ = data.load_client_data(clients_data, fedargs.client_batch_size, None, **kwargs)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=fedargs.test_batch_size, shuffle=True, **kwargs)

clients_info = {
        client: {"train_loader": client_train_loaders[client]}
        for client in clients
    }

# %%
import asyncio
import time

def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def process(client, epoch, model, train_loader, fedargs, device):
    # Train
    model, loss = train_model(model, train_loader, fedargs, device)

    #Plot and Log
    for local_epoch, loss in enumerate(list(loss.values())):
        fedargs.tb.add_scalars("Training Loss/" + client, {str(epoch): loss}, str(local_epoch + 1))

    log.jsondebug(loss, "Epoch {} of {} : Federated Training loss, Client {}".format(epoch, fedargs.epochs, client))
    log.modeldebug(model, "Epoch {} of {} : Client {} Update".format(epoch, fedargs.epochs, client))
    
    return model

# %%
import time
start_time = time.time()
    
# Federated Training
for _epoch in tqdm(range(fedargs.epochs)):

    epoch = _epoch + 1
    log.info("Federated Training Epoch {} of {}".format(epoch, fedargs.epochs))

    # Gloabal Model Update
    if epoch > 1:
        # Average
        global_model = fl.federated_avg(client_models)
        log.modeldebug(global_model, "Epoch {} of {} : Server Update".format(epoch, fedargs.epochs))

        # Test
        global_test_output = fl.eval(global_model, test_loader, device, 4, 9)
        fedargs.tb.add_scalar("Gloabl Accuracy/", global_test_output["accuracy"], epoch)
        log.jsoninfo(global_test_output, "Gloabl Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))
    
        # Update client models
        client_models = {client: copy.deepcopy(global_model) for client in clients}

    # Clients
    loop = asyncio.get_event_loop()
    tasks = [process(client, epoch, client_models[client],
                     clients_info[client]['train_loader'],
                     fedargs, device) for client in clients]
    updates = loop.run_until_complete(asyncio.gather(*tasks))
    client_models = {client: update for client, update in zip(clients, updates)}
    
print(time.time() - start_time)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]2021-08-17 07:03:23,966 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 1 of 10 [MainProcess : MainThread (INFO)]
#  10%|█         | 1/10 [00:38<05:47, 38.64s/it]2021-08-17 07:04:02,407 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 2 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:04:08,124 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 2 of 10 {
#     "accuracy": 74.76,
#     "attack": {
#         "attack_success_count": 270,
#         "attack_success_rate": 27.494908350305497,
#         "instances": 982,
#         "misclassification_rate": 37.270875763747455,
#         "misclassifications": 366
#     },
#     "correct": 7476,
#     "test_loss": 1.4833585876464843
# } [MainProcess : MainThread (INFO)]
#  20%|██        | 2/10 [01:22<05:32, 41.55s/it]2021-08-17 07:04:46,001 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 3 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:04:52,099 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 3 of 10 {
#     "accuracy": 85.28999999999999,
#     "attack": {
#         "attack_success_count": 128,
#         "attack_success_rate": 13.034623217922606,
#         "instances": 982,
#         "misclassification_rate": 19.45010183299389,
#         "misclassifications": 191
#     },
#     "correct": 8529,
#     "test_loss": 0.6734565024375916
# } [MainProcess : MainThread (INFO)]
#  30%|███       | 3/10 [02:06<04:59, 42.73s/it]2021-08-17 07:05:30,131 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 4 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:05:35,966 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 4 of 10 {
#     "accuracy": 88.4,
#     "attack": {
#         "attack_success_count": 87,
#         "attack_success_rate": 8.859470468431772,
#         "instances": 982,
#         "misclassification_rate": 13.441955193482688,
#         "misclassifications": 132
#     },
#     "correct": 8840,
#     "test_loss": 0.467401487159729
# } [MainProcess : MainThread (INFO)]
#  40%|████      | 4/10 [02:50<04:20, 43.45s/it]2021-08-17 07:06:14,677 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 5 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:06:20,706 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 5 of 10 {
#     "accuracy": 90.09,
#     "attack": {
#         "attack_success_count": 58,
#         "attack_success_rate": 5.906313645621181,
#         "instances": 982,
#         "misclassification_rate": 9.470468431771895,
#         "misclassifications": 93
#     },
#     "correct": 9009,
#     "test_loss": 0.3848523031711578
# } [MainProcess : MainThread (INFO)]
#  50%|█████     | 5/10 [03:34<03:38, 43.66s/it]2021-08-17 07:06:58,714 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 6 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:07:04,718 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 6 of 10 {
#     "accuracy": 91.10000000000001,
#     "attack": {
#         "attack_success_count": 53,
#         "attack_success_rate": 5.39714867617108,
#         "instances": 982,
#         "misclassification_rate": 8.350305498981669,
#         "misclassifications": 82
#     },
#     "correct": 9110,
#     "test_loss": 0.3355116745710373
# } [MainProcess : MainThread (INFO)]
#  60%|██████    | 6/10 [04:16<02:51, 42.85s/it]2021-08-17 07:07:39,999 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 7 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:07:46,327 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 7 of 10 {
#     "accuracy": 91.78,
#     "attack": {
#         "attack_success_count": 39,
#         "attack_success_rate": 3.971486761710794,
#         "instances": 982,
#         "misclassification_rate": 6.619144602851323,
#         "misclassifications": 65
#     },
#     "correct": 9178,
#     "test_loss": 0.3042747094154358
# } [MainProcess : MainThread (INFO)]
#  70%|███████   | 7/10 [04:59<02:08, 42.90s/it]2021-08-17 07:08:23,011 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 8 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:08:29,196 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 8 of 10 {
#     "accuracy": 92.28,
#     "attack": {
#         "attack_success_count": 41,
#         "attack_success_rate": 4.1751527494908345,
#         "instances": 982,
#         "misclassification_rate": 6.619144602851323,
#         "misclassifications": 65
#     },
#     "correct": 9228,
#     "test_loss": 0.2805393324375153
# } [MainProcess : MainThread (INFO)]
#  80%|████████  | 8/10 [05:41<01:25, 42.70s/it]2021-08-17 07:09:05,275 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 9 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:09:11,606 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 9 of 10 {
#     "accuracy": 92.94,
#     "attack": {
#         "attack_success_count": 34,
#         "attack_success_rate": 3.462321792260693,
#         "instances": 982,
#         "misclassification_rate": 5.906313645621181,
#         "misclassifications": 58
#     },
#     "correct": 9294,
#     "test_loss": 0.2598796200752258
# } [MainProcess : MainThread (INFO)]
#  90%|█████████ | 9/10 [06:23<00:42, 42.61s/it]2021-08-17 07:09:47,686 - <ipython-input-11-309b56541d0e>::<module>(l:8) : Federated Training Epoch 10 of 10 [MainProcess : MainThread (INFO)]
# 2021-08-17 07:09:53,767 - <ipython-input-11-309b56541d0e>::<module>(l:19) : Gloabl Test Outut after Epoch 10 of 10 {
#     "accuracy": 93.28,
#     "attack": {
#         "attack_success_count": 32,
#         "attack_success_rate": 3.2586558044806515,
#         "instances": 982,
#         "misclassification_rate": 5.7026476578411405,
#         "misclassifications": 56
#     },
#     "correct": 9328,
#     "test_loss": 0.24400619595050813
# } [MainProcess : MainThread (INFO)]
# 100%|██████████| 10/10 [07:06<00:00, 42.65s/it]
# 426.52143692970276
